# %%
# Download necessary libraries
import pandas as pd 
import numpy as np 
from datetime import date 

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import VarianceThreshold

# %%
team_statistics_original = pd.read_csv('TeamStatistics.csv')

# %%
team_statistics_original.head()
# Out:
#      gameId             gameDate      teamCity  teamName      teamId  \
# 0  42400156  2025-05-02 21:00:00  Golden State  Warriors  1610612744
# 1  42400156  2025-05-02 21:00:00       Houston   Rockets  1610612745
# 2  42400176  2025-05-01 22:00:00        Denver   Nuggets  1610612743
# 3  42400176  2025-05-01 22:00:00   Los Angeles  Clippers  1610612746
# 4  42400126  2025-05-01 19:30:00      New York    Knicks  1610612752
#
#   opponentTeamCity opponentTeamName  opponentTeamId  home  win  ...  \
# 0          Houston          Rockets      1610612745     1    0  ...
# 1     Golden State         Warriors      1610612744     0    1  ...
# 2      Los Angeles         Clippers      1610612746     0    0  ...
# 3           Denver          Nuggets      1610612743     1    1  ...
# 4          Detroit          Pistons      1610612765     0    1  ...
#
#    leadChanges  pointsFastBreak  pointsFromTurnovers  pointsInThePaint  \
# 0         10.0             28.0                 12.0              32.0
# 1         10.0             11.0                 24.0              42.0
# 2         14.0             12.0                 10.0              56.0
# 3         14.0             11.0                 23.0              50.0
# 4          6.0             18.0                 11.0              48.0
#
#    pointsSecondChance  timesTied  timeoutsRemaining  seasonWins  seasonLosses  \
# 0                12.0        3.0                0.0         3.0           3.0
# 1                19.0        3.0                0.0         3.0           3.0
# 2                17.0        2.0                0.0         3.0           3.0
# 3                17.0        2.0                0.0         3.0           3.0
# 4                18.0        7.0                0.0         4.0           2.0
#
#    coachId
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 48 columns]
